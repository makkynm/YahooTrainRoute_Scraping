# %%
#必要なライブラリをインポート
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time

# %%
#input fileの読み込み tab区切り
InputFilePath = "StationCombination.csv"
df_base = pd.read_table(InputFilePath)
SearchURLs = df_base["SearchURL"].values.tolist()
Origins = df_base["Origin"].values.tolist()
Destinations = df_base["Destination"].values.tolist()

# %%
# Revised Version
Results = []
HeaderNames = ["SearchURL", "Origin", "Destination", "Time", "Fare", "Transfer", "Priority","Comment"]

for iURL, url in enumerate(SearchURLs):
    print(str(iURL+1) + " / " + str(len(SearchURLs)))
    try:
        #データ取得
#         url.replace("&ya=2021", "&ya=2022")
        result = requests.get(url)
        c = result.content
        #HTMLを元に、オブジェクトを作る
        soup = BeautifulSoup(c, "html.parser")
        #ページ数を取得
        body = soup.find("body")
        RouteListElem = body.find(id = 'route_list').find("nav",{'class':'navRouteList'})
        
        if RouteListElem == None:
            ErrorElem = body.find("div",{'class':'boxError'})
            ErrorMessage = ErrorElem.get_text()
#             ErrorMessage = ""
            Detail = [SearchURLs[iURL], Origins[iURL], Destinations[iURL], "", "", "", "", ErrorMessage]
            Results.append(Detail) 
            time.sleep(1)
        else:
            WarningElem = body.find("dl",{'class':'boxResearch'})
            if WarningElem == None:
                Comment = ""
            else:
                Comment = WarningElem.get_text()
            
            TimeElem = RouteListElem.find_all("li",{'class':'time'})
            Times = [elem.find_all("span",{'class':'small'})[-1].get_text() for elem in TimeElem]
            Time = ' --- '.join(Times)

            FareElem = RouteListElem.find_all("li",{'class':'fare'})
            Fares = [elem.get_text() for elem in FareElem]
            Fare = ' --- '.join(Fares)

            TransferElem = RouteListElem.find_all("li",{'class':'transfer'})
            Transfers = [elem.get_text() for elem in TransferElem]
            Transfer = ' --- '.join(Transfers)    

            PriorityElem = RouteListElem.find_all("li",{'class':'priority'})
            Priorities = [elem.get_text() for elem in PriorityElem]
            Priority = ' --- '.join(Priorities)  

            Detail = [SearchURLs[iURL], Origins[iURL], Destinations[iURL], Time, Fare, Transfer, Priority,Comment]
            Results.append(Detail)
            time.sleep(2)
    except requests.exceptions.RequestException as e:
        print("エラー : ",e)
        time.sleep(2)

df = pd.DataFrame(Results, columns = HeaderNames)
filename = "Yahoo_Route.csv"
df.to_csv(filename)
# Out:
# 1 / 65
# 2 / 65
# 3 / 65
# 4 / 65
# 5 / 65
# 6 / 65
# 7 / 65
# 8 / 65
# 9 / 65
# 10 / 65
# 11 / 65
# 12 / 65
# 13 / 65
# 14 / 65
# 15 / 65
# 16 / 65
# 17 / 65
# 18 / 65
# 19 / 65
# 20 / 65
# 21 / 65
# 22 / 65
# 23 / 65
# 24 / 65
# 25 / 65
# 26 / 65
# 27 / 65
# 28 / 65
# 29 / 65
# 30 / 65
# 31 / 65
# 32 / 65
# 33 / 65
# 34 / 65
# 35 / 65
# 36 / 65
# 37 / 65
# 38 / 65
# 39 / 65
# 40 / 65
# 41 / 65
# 42 / 65
# 43 / 65
# 44 / 65
# 45 / 65
# 46 / 65
# 47 / 65
# 48 / 65
# 49 / 65
# 50 / 65
# 51 / 65
# 52 / 65
# 53 / 65
# 54 / 65
# 55 / 65
# 56 / 65
# 57 / 65
# 58 / 65
# 59 / 65
# 60 / 65
# 61 / 65
# 62 / 65
# 63 / 65
# 64 / 65
# 65 / 65

# %% [raw]
# # Normal Version
# Results = []
# HeaderNames = ["SearchURL", "Origin", "Destination", "Time", "Fare", "Transfer", "Priority","Comment"]
#
# for iURL, url in enumerate(SearchURLs):
#     print(str(iURL+1) + " / " + str(len(SearchURLs)))
#     try:
#         #データ取得
#         url.replace("&ya=2021", "&ya=2022")
#         result = requests.get(url)
#         c = result.content
#         #HTMLを元に、オブジェクトを作る
#         soup = BeautifulSoup(c, "html.parser")
#         #ページ数を取得
#         body = soup.find("body")
#         RouteListElem = body.find("ul",{'class':'routeList'})
#
#         if RouteListElem == None:
#             ErrorElem = body.find("div",{'class':'boxError'})
#             ErrorMessage = ErrorElem.get_text()
# #             ErrorMessage = ""
#             Detail = [SearchURLs[iURL], Origins[iURL], Destinations[iURL], "", "", "", "", ErrorMessage]
#             Results.append(Detail)
#             time.sleep(1)
#         else:
#             WarningElem = body.find("dl",{'class':'boxResearch'})
#             if WarningElem == None:
#                 Comment = ""
#             else:
#                 Comment = WarningElem.get_text()
#
#             TimeElem = RouteListElem.find_all("li",{'class':'time'})
#             Times = [elem.find("span",{'class':'small'}).get_text() for elem in TimeElem]
#             Time = ' --- '.join(Times)
#
#             FareElem = RouteListElem.find_all("li",{'class':'fare'})
#             Fares = [elem.get_text() for elem in FareElem]
#             Fare = ' --- '.join(Fares)
#
#             TransferElem = RouteListElem.find_all("li",{'class':'transfer'})
#             Transfers = [elem.get_text() for elem in TransferElem]
#             Transfer = ' --- '.join(Transfers)
#
#             PriorityElem = RouteListElem.find_all("li",{'class':'priority'})
#             Priorities = [elem.get_text() for elem in PriorityElem]
#             Priority = ' --- '.join(Priorities)
#
#             Detail = [SearchURLs[iURL], Origins[iURL], Destinations[iURL], Time, Fare, Transfer, Priority,Comment]
#             Results.append(Detail)
#             time.sleep(5)
#     except requests.exceptions.RequestException as e:
#         print("エラー : ",e)
#         time.sleep(5)
#
# df = pd.DataFrame(Results, columns = HeaderNames)
# filename = "Yahoo_Route.csv"
# df.to_csv(filename)

# %% [markdown]
# # Debug
# df = pd.DataFrame(Results, columns = HeaderNames)
# filename = "Yahoo_Route.csv"
# df.to_csv(filename)

# %% [raw]
# #html ファイルの書き出し
# file = open('Result.html', 'w')
# file.write(str(soup))
# file.close()

# %% [raw]
# # Debug for revised version
# RouteListElem = body.find(id = 'route_list').find("nav",{'class':'navRouteList'})
# WarningElem = body.find("dl",{'class':'boxResearch'})
# if WarningElem == None:
#     Comment = ""
# else:
#     Comment = WarningElem.get_text()
# TimeElem = RouteListElem.find_all("li",{'class':'time'})
# Times = [elem.find_all("span",{'class':'small'})[-1].get_text() for elem in TimeElem]
# Time = ' --- '.join(Times)
#
# FareElem = RouteListElem.find_all("li",{'class':'fare'})
# Fares = [elem.get_text() for elem in FareElem]
# Fare = ' --- '.join(Fares)
#
# TransferElem = RouteListElem.find_all("li",{'class':'transfer'})
# Transfers = [elem.get_text() for elem in TransferElem]
# Transfer = ' --- '.join(Transfers)
#
# PriorityElem = RouteListElem.find_all("li",{'class':'priority'})
# Priorities = [elem.get_text() for elem in PriorityElem]
# Priority = ' --- '.join(Priorities)
#
# Detail = [SearchURLs[iURL], Origins[iURL], Destinations[iURL], Time, Fare, Transfer, Priority,Comment]
# Results.append(Detail)

# %% [markdown]
# # Debug
# #827 -> 北山田　東京
# #829 => 北山田 センター南
#
# iURL = 827
# url = SearchURLs[iURL]
# Results = []
# HeaderNames = ["SearchURL", "Origin", "Destination", "Time", "Fare", "Transfer", "Priority","Comment"]
#
# print(url)
#
# print(str(iURL+1) + " / " + str(len(SearchURLs)))
# #データ取得
# result = requests.get(url)
# c = result.content
# #HTMLを元に、オブジェクトを作る
# soup = BeautifulSoup(c, "html.parser")
# #ページ数を取得
# body = soup.find("body")
# RouteListElem = body.find("ul",{'class':'routeList'})
#
# #     Times = [elem.find("span",{'class':'small'}).get_text() for elem in TimeElem]
#
# #     FareElem = RouteListElem.find_all("li",{'class':'fare'})
# #     Fare = [elem.get_text() for elem in FareElem]
#
# #     TransferElem = RouteListElem.find_all("li",{'class':'transfer'})
# #     Transfer = [elem.get_text() for elem in TransferElem]
#
# #     PriorityElem = RouteListElem.find_all("li",{'class':'priority'})
# #     Priority = [elem.get_text() for elem in PriorityElem]

# %% [markdown]
# if RouteListElem == None:
#     ErrorElem = body.find("div",{'class':'boxError'})
#     ErrorMessage = ErrorElem.get_text()
#     Detail = [SearchURLs[iURL], Origins[iURL], Destinations[iURL], "", "", "", "", ErrorMessage]
#     Results.append(Detail)
#     time.sleep(5)
# else:
#     WarningElem = body.find("dl",{'class':'boxResearch'})
#     if WarningElem == None:
#         Comment = ""
#     else:
#         Comment = WarningElem.get_text()
#
#     TimeElem = RouteListElem.find_all("li",{'class':'time'})
#     Times = [elem.find("span",{'class':'small'}).get_text() for elem in TimeElem]
#     Time = ' --- '.join(Times)
#
#     FareElem = RouteListElem.find_all("li",{'class':'fare'})
#     Fares = [elem.get_text() for elem in FareElem]
#     Fare = ' --- '.join(Fares)
#
#     TransferElem = RouteListElem.find_all("li",{'class':'transfer'})
#     Transfers = [elem.get_text() for elem in TransferElem]
#     Transfer = ' --- '.join(Transfers)
#
#     PriorityElem = RouteListElem.find_all("li",{'class':'priority'})
#     Priorities = [elem.get_text() for elem in PriorityElem]
#     Priority = ' --- '.join(Priorities)
#     Detail = [SearchURLs[iURL], Origins[iURL], Destinations[iURL], Time, Fare, Transfer, Priority,Comment]
#     Results.append(Detail)
